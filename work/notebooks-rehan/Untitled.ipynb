# %%
import pandas as pd

# %%
import os

# %%
df = pd.read_csv('../data/merged_dataset.csv')

# %%
df[df['Series_x']=='Intentional homicide rates per 100,000']
# Out:
#        Unnamed: 0                         Region  Year  \
# 0               1  Total, all countries or areas  2005
# 1               2  Total, all countries or areas  2005
# 2               4  Total, all countries or areas  2005
# 3               5  Total, all countries or areas  2005
# 4               7  Total, all countries or areas  2005
# ...           ...                            ...   ...
# 11401       18906                         Zambia  2010
# 11402       18908                         Zambia  2015
# 11403       18909                         Zambia  2015
# 11404       18918                       Zimbabwe  2010
# 11405       18919                       Zimbabwe  2010
#
#                                      Series_x  Value_x  \
# 0      Intentional homicide rates per 100,000   6.2935
# 1      Intentional homicide rates per 100,000   6.2935
# 2      Intentional homicide rates per 100,000   6.2935
# 3      Intentional homicide rates per 100,000   6.2935
# ...
